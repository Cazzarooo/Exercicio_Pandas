# %% [markdown]
# <a href="https://colab.research.google.com/github/Cazzarooo/Exercicio_Pandas/blob/main/Exercicio_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv('/content/fifa.csv')

# %%
dados
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   31
# 1               1   20801  Cristiano Ronaldo   33
# 2               2  190871          Neymar Jr   26
# 3               3  193080             De Gea   27
# 4               4  192985       K. De Bruyne   27
# ...           ...     ...                ...  ...
# 12482       12482  239724      S. Puttkammer   29
# 12483       12483  244588           B. Baiye   17
# 12484       12484  197998       A. Andersson   27
# 12485       12485  229998           D. Schad   21
# 12486       12486  238446              Tachi   20
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
# Para abrir um arquivo XLSX
# dados_xslx = pd.read_excel('/content/fifa.xslx')

# %%
# Para abrir um arquivo TXT
# dados_txt = pd.read_csv('/content/fifa.txt', delimiter = '\t')

# %%
# Para abrir um arquivo pagina web
# dados_html = pd.read_html('Link da pagina web')

# %%
#dados_html = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_presidentes_dos_Estados_Unidos')

# %%
#dados_html
# Out:
# [    N.º  Presidente       Presidente.1  \
#  0     1         NaN  George Washington
#  1     1         NaN  George Washington
#  2     2         NaN         John Adams
#  3     3         NaN   Thomas Jefferson
#  4     3         NaN   Thomas Jefferson
#  ..  ...         ...                ...
#  77   43         NaN     George W. Bush
#  78   44         NaN       Barack Obama
#  79   44         NaN       Barack Obama
#  80   45         NaN       Donald Trump
#  81   46         NaN          Joe Biden
#
#                                            Mandato  Partido  \
#  0        30 de abril de 1789 – 4 de março de 1797      NaN
#  1        30 de abril de 1789 – 4 de março de 1797      NaN
#  2         4 de março de 1797 – 4 de março de 1801      NaN
#  3         4 de março de 1801 – 4 de março de 1809      NaN
#  4         4 de março de 1801 – 4 de março de 1809      NaN
#  ..                                            ...      ...
# ...

# %%
dados.head(2)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
#
#                                   Flag  Overall  Potential          Club  ...  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona  ...
# 1  https://cdn.sofifa.org/flags/38.png       94         94      Juventus  ...
#
#   Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 0        96      33             28             26        6        11.0
# 1        95      28             31             23        7        11.0
#
#    GKKicking  GKPositioning GKReflexes Release Clause
# 0       15.0           14.0        8.0        €226.5M
# 1       15.0           14.0       11.0        €127.1M
#
# ...

# %%
dados.tail(8)
# Out:
#        Unnamed: 0      ID             Name  Age  \
# 12479       12479  239211  B. Moussiti-Oko   23
# 12480       12480  196972         L. Sætra   26
# 12481       12481  238956          D. Bock   23
# 12482       12482  239724    S. Puttkammer   29
# 12483       12483  244588         B. Baiye   17
# 12484       12484  197998     A. Andersson   27
# 12485       12485  229998         D. Schad   21
# 12486       12486  238446            Tachi   20
#
#                                                 Photo Nationality  \
# 12479  https://cdn.sofifa.org/players/4/19/239211.png       Congo
# 12480  https://cdn.sofifa.org/players/4/19/196972.png      Norway
# 12481  https://cdn.sofifa.org/players/4/19/238956.png     Germany
# 12482  https://cdn.sofifa.org/players/4/19/239724.png     Germany
# 12483  https://cdn.sofifa.org/players/4/19/244588.png     Belgium
# 12484  https://cdn.sofifa.org/players/4/19/197998.png      Sweden
# ...

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
dados.index
# Out:
# RangeIndex(start=0, stop=12487, step=1)

# %%
dados[['Name', 'Weight', 'Nationality']]
# Out:
#                     Name  Weight Nationality
# 0               L. Messi  159lbs   Argentina
# 1      Cristiano Ronaldo  183lbs    Portugal
# 2              Neymar Jr  150lbs      Brazil
# 3                 De Gea  168lbs       Spain
# 4           K. De Bruyne  154lbs     Belgium
# ...                  ...     ...         ...
# 12482      S. Puttkammer  179lbs     Germany
# 12483           B. Baiye  165lbs     Belgium
# 12484       A. Andersson  181lbs      Sweden
# 12485           D. Schad  154lbs     Germany
# 12486              Tachi  165lbs       Spain
#
# [12487 rows x 3 columns]

# %%
dados.iloc[0:4]
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# ...

# %%
dados.iloc[2,2]
# Out:
# 'Neymar Jr'

# %%
dados.loc[dados['Age'] == 35]
# Out:
#        Unnamed: 0      ID          Name  Age  \
# 102           102  171919         Naldo   35
# 108           108  120533          Pepe   35
# 221           221  156616     F. Ribéry   35
# 224           224   24630    Pepe Reina   35
# 314           314  146530    Dani Alves   35
# ...           ...     ...           ...  ...
# 12187       12187  181021    D. Djulbic   35
# 12208       12208   11811      P. Green   35
# 12210       12210  171555      J. Mucha   35
# 12328       12328  208196     M. Aceval   35
# 12408       12408   27480  T. Zwarthoed   35
#
#                                                 Photo          Nationality  \
# 102    https://cdn.sofifa.org/players/4/19/171919.png               Brazil
# 108    https://cdn.sofifa.org/players/4/19/120533.png             Portugal
# 221    https://cdn.sofifa.org/players/4/19/156616.png               France
# 224     https://cdn.sofifa.org/players/4/19/24630.png                Spain
# ...

# %%
dados.sort_values(['Weight'], ascending = False)
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 9501         9501  156321   A. Akinfenwa   36
# 8652         8652  179685       C. Seitz   31
# 8908         8908  195357    F. Farnolle   33
# 11894       11894  190169  D. Telgenkamp   31
# 1426         1426  199833  L. Unnerstall   27
# ...           ...     ...            ...  ...
# 9485         9485  244892        S. Diop   18
# 11759       11759  237498    T. Figueroa   19
# 4460         4460  220064     C. Aboagye   23
# 7126         7126  225150      A. Araujo   21
# 4390         4390  214919       D. Rojas   23
#
#                                                 Photo    Nationality  \
# 9501   https://cdn.sofifa.org/players/4/19/156321.png        England
# 8652   https://cdn.sofifa.org/players/4/19/179685.png  United States
# 8908   https://cdn.sofifa.org/players/4/19/195357.png          Benin
# 11894  https://cdn.sofifa.org/players/4/19/190169.png    Netherlands
# ...

# %%
dados['Total'] = dados['Acceleration'] + dados['Agility'] + dados['Reactions']
dados
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   31
# 1               1   20801  Cristiano Ronaldo   33
# 2               2  190871          Neymar Jr   26
# 3               3  193080             De Gea   27
# 4               4  192985       K. De Bruyne   27
# ...           ...     ...                ...  ...
# 12482       12482  239724      S. Puttkammer   29
# 12483       12483  244588           B. Baiye   17
# 12484       12484  197998       A. Andersson   27
# 12485       12485  229998           D. Schad   21
# 12486       12486  238446              Tachi   20
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
dados = dados[['Name', 'Total']]
dados.sort_values('Total', ascending = False)
# Out:
#                 Name  Total
# 2          Neymar Jr    284
# 5          E. Hazard    279
# 0           L. Messi    277
# 26          M. Salah    276
# 60       R. Sterling    275
# ...              ...    ...
# 7221     H. Sogahata     97
# 8922   Jailson Acuna     96
# 10380     G. Poussin     94
# 12433      S. Müller     90
# 11583     A. Tarbell     90
#
# [12487 rows x 2 columns]

# %%
#Salvando em formato csv

dados.to_csv('dados1.csv', index = False)

# %%
#Salvando em formato Excel

dados.to_excel('dados2.xlsx', index = False)

# %%
#Salvando em formato txt

dados.to_csv('dados3.txt', index = False, sep = '\t')
